# %% [markdown]
# Data Merger

# %%
#Environment Setup

import numpy as np
import pandas as pd
import warnings

# %%
pd.options.display.max_columns = None
warnings.simplefilter(action='ignore')

# %%
credit_df = pd.read_csv('Data/Loan Data/loan_data_2007_2014.csv')
credit_df.tail()
# Out:
#              id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 466280  8598660    1440975      18400        18400          18400.0
# 466281  9684700   11536848      22000        22000          22000.0
# 466282  9584776   11436914      20700        20700          20700.0
# 466283  9604874   11457002       2000         2000           2000.0
# 466284  9199665   11061576      10000        10000           9975.0
#
#               term  int_rate  installment grade sub_grade  \
# 466280   60 months     14.47       432.64     C        C2
# 466281   60 months     19.97       582.50     D        D5
# 466282   60 months     16.99       514.34     D        D1
# 466283   36 months      7.90        62.59     A        A4
# 466284   36 months     19.20       367.58     D        D3
#
#                                     emp_title emp_length home_ownership  \
# 466280                     Financial Advisor     4 years       MORTGAGE
# ...

# %%
CPI_df = pd.read_excel('Data/Macroeconomic Data/CPI(U).xlsx')
CPI_df.tail()
# Out:
#    Year      Jan      Feb      Mar      Apr      May      Jun      Jul  \
# 5  2011  220.223  221.309  223.467  224.906  225.964  225.722  225.922
# 6  2012  226.665  227.663  229.392  230.085  229.815  229.478  229.104
# 7  2013  230.280  232.166  232.773  232.531  232.945  233.504  233.596
# 8  2014  233.916  234.781  236.293  237.072  237.900  238.343  238.250
# 9  2015  233.707  234.722  236.119  236.599  237.805  238.638  238.654
#
#        Aug      Sep      Oct      Nov      Dec    HALF1    HALF2
# 5  226.545  226.889  226.421  226.230  225.672  223.598  226.280
# 6  230.379  231.407  231.317  230.221  229.601  228.850  230.338
# 7  233.877  234.149  233.546  233.069  233.049  232.366  233.548
# 8  237.852  238.031  237.433  236.151  234.812  236.384  237.088
# 9  238.316  237.945  237.838  237.336  236.525  236.265  237.769

# %%
Inflation_CPI_df = pd.DataFrame(columns=['Year', 'Inflation CPI'])
Inflation_CPI_df['Year'] = CPI_df['Year'].drop(index=[0,9])

# %% [markdown]
# Inflation Rate = [CPI(n+1) - CPI(n) * 100] / CPI(n)

# %%
for i in range(len(CPI_df)-2):
    Inflation_CPI_df['Inflation CPI'].iloc[i] = (CPI_df.drop(columns=['Year', 'HALF1', 'HALF2']).iloc[i+1].sum() - CPI_df.drop(columns=['Year', 'HALF1', 'HALF2']).iloc[i].sum())*100 / CPI_df.drop(columns=['Year', 'HALF1', 'HALF2']).iloc[i].sum()

# %%
Inflation_CPI_df['Inflation CPI'] = Inflation_CPI_df['Inflation CPI'].astype(np.float64)

# %%
Inflation_CPI_df
# Out:
#    Year  Inflation CPI
# 1  2007       2.852672
# 2  2008       3.839100
# 3  2009      -0.355546
# 4  2010       1.640043
# 5  2011       3.156842
# 6  2012       2.069337
# 7  2013       1.464833
# 8  2014       1.622223

# %%
GDP_df = pd.read_csv('Data/Macroeconomic Data/GDP.csv')
GDP_df.head()
# Out:
#    Line                         Unnamed: 1     2006     2007     2008  \
# 0  Line                                NaN      NaN      NaN      NaN
# 1     1             Gross domestic product  13815.6  14474.2  14769.9
# 2     2  Personal consumption expenditures   9277.2   9746.6  10050.1
# 3     3                              Goods   3239.7   3367.0   3363.2
# 4     4                      Durable goods   1158.3   1188.0   1098.8
#
#       2009     2010     2011     2012     2013     2014     2015
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1  14478.1  15049.0  15599.7  16254.0  16843.2  17550.7  18206.0
# 2   9891.2  10260.3  10698.9  11047.4  11363.5  11847.7  12263.5
# 3   3180.0   3317.8   3518.1   3637.7   3730.0   3863.0   3923.0
# 4   1012.1   1049.0   1093.5   1144.2   1189.4   1242.1   1307.6

# %%
GDP_df = GDP_df.drop([0])

# %%
GDP_df = pd.DataFrame(GDP_df.iloc[0].transpose())
GDP_df.head()
# Out:
#                                          1
# Line                                     1
# Unnamed: 1          Gross domestic product
# 2006                               13815.6
# 2007                               14474.2
# 2008                               14769.9

# %%
GDP_df = GDP_df.drop(['Line', 'Unnamed: 1'])

# %%
Year = GDP_df.index

# %%
GDP_df = pd.DataFrame(GDP_df.values)

# %%
GDP_df['Year'] = Year
GDP_df = GDP_df.rename(columns={0:'GDP'})

# %%
GDP_df['Year'] = GDP_df['Year'].astype(np.int64)
GDP_df['GDP'] = GDP_df['GDP'].astype(np.float64)

# %%
GDP_df.head()
# Out:
#        GDP  Year
# 0  13815.6  2006
# 1  14474.2  2007
# 2  14769.9  2008
# 3  14478.1  2009
# 4  15049.0  2010

# %%
USD_df = pd.read_csv('Data/Macroeconomic Data/Nominal_Broad_USD_Index.csv')
USD_df.head()
# Out:
#          DATE  DTWEXBGS
# 0  2006-01-02  101.4155
# 1  2006-01-03  100.7558
# 2  2006-01-04  100.2288
# 3  2006-01-05  100.2992
# 4  2006-01-06  100.0241

# %%
USD_df['DATE'] = USD_df['DATE'].str.split('-').str[0].astype(int)

# %%
USD_df = USD_df.replace('.', 100)

# %%
USD_df['DTWEXBGS'] = USD_df['DTWEXBGS'].astype(np.float64)

# %%
USD_ind_df = USD_df.groupby(['DATE'], as_index=False).mean()

# %%
USD_ind_df['DATE']
# Out:
# 0    2006
# 1    2007
# 2    2008
# 3    2009
# 4    2010
# 5    2011
# 6    2012
# 7    2013
# 8    2014
# 9    2015
# Name: DATE, dtype: int32

# %%
USD_ind_df.head()
# Out:
#    DATE   DTWEXBGS
# 0  2006  98.600466
# 1  2007  93.833682
# 2  2008  90.880132
# 3  2009  96.900309
# 4  2010  93.453325

# %%
credit_df['issue_d'] = credit_df['issue_d'].str.split('-').str[1]

# %%
credit_df['issue_d'] = credit_df['issue_d'].apply(lambda x : '20' + x).astype(np.int64)

# %%
Inflation_CPI_df[Inflation_CPI_df['Year'] == 2011]['Inflation CPI']
# Debugging
# Out:
# 5    3.156842
# Name: Inflation CPI, dtype: float64

# %%
credit_df['Inflation CPI Rate'] = pd.Series()
row = 0
for i in credit_df['issue_d']:
    credit_df['Inflation CPI Rate'].iloc[row] = Inflation_CPI_df[Inflation_CPI_df['Year']==i]['Inflation CPI']
    row +=1

# %%
credit_df['GDP'] = pd.Series()
row = 0
for i in credit_df['issue_d']:
    credit_df['GDP'].iloc[row] = GDP_df[GDP_df['Year']==i]['GDP']
    row +=1

# %%
credit_df['USD_Index_Rate'] = pd.Series()
row = 0
for i in credit_df['issue_d']:
    credit_df['USD_Index_Rate'].iloc[row] = USD_ind_df[USD_ind_df['DATE']==i]['DTWEXBGS']
    row +=1

# %%
credit_df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0     10.65       162.87     B        B2                       NaN  10+ years
# 1     15.27        59.83     C        C4                     Ryder   < 1 year
# 2     15.96        84.33     C        C5                       NaN  10+ years
# 3     13.49       339.31     C        C1       AIR RESOURCES BOARD  10+ years
# 4     12.69        67.79     B        B5  University Medical Group     1 year
#
# ...

# %%
credit_df.to_csv("Data/Loan Data/Merged_Data.csv")
